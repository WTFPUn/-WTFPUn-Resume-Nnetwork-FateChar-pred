# %%
from PIL import  Image
y = 1
x = f'Saber{y}.jpg'


#print(image.format)
#print(image.size)
#print(image.mode)

from matplotlib import image
from matplotlib import pyplot
# %matplotlib inline

#image = image.imread(x)
#print(image.dtype)
#print(image.shape)

import numpy as np

#data = Image.fromarray(image)
#print(data.size)
#data = np.asarray(image)
#print(data.shape)
for i in range(4):
    x = f'Saber{y}.jpg'
    image = Image.open(x)
    #print(image.size)
    newimg = np.array(Image.open(x).resize((200,200)))
    
    if i == 0:
        new = np.reshape(newimg,(1,-1)).tolist()
        new = np.array(new)
        print(new.shape)
    else:
        newn = np.reshape(newimg,(1,-1)).tolist()
        new = np.append(new,newn)
        print(new.shape)
    pyplot.imshow(newimg)
    pyplot.show()    
    y = y + 1

new = new.reshape(-1,120000)
print(new.shape)
# Out:
# (1, 120000)
# (240000,)
# (360000,)
# (480000,)
# (4, 120000)
